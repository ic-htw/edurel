# %% [markdown]
# # Import / Config

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

from IPython.display import Markdown, display

import edurel.utils.dbcon as dbcu
import edurel.utils.db as dbu
import edurel.utils.duckdb as ddbu
import edurel.utils.llm as llmu
import edurel.utils.llmchat as llmc
import edurel.utils.yaml as yu
import edurel.widgets.mermaid_viz as mmw
import edurel.widgets.chatman as cmw
import edurel.utils.misc as mu

load_dotenv() 
BASE_DIR = os.getenv("BASE_DIR")
DB_DIR = f"{BASE_DIR}/databases"

# %% [markdown]
# # Database

# %%
con = dbcu.company_en()
# additional_fks = {}
additional_fks = {"Orgunit": ["Employee|Head|EID", "OrgUnit|SuperUnit|OEID"]}

db = dbu.DbHandler(con,additional_fks=additional_fks)
yaml = db.schema_yaml_str(["nullable", "fkname"])

# %%
spec = """
del table index: [0:2, 3]
del column OrgUnit index: [1:]
"""

print(yu.yaml_to_yaml(yaml, spec))
# Out:
# tables:
# - tablename: OrgUnit
#   columns:
#   - columnname: OUID
#     type: INTEGER
#   primary_key:
#   - OUID
