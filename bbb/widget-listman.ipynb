# %% [markdown]
# # Import / Config

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
import edurel.widgets.listman as lmw

# %% [markdown]
# # ListManager

# %%
manager = lmw.ListManager(filename="tasks.json")
manager.display()

# %%
manager.get_selected_items()
