# %% [markdown]
# # Import / Config

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
import edurel.utils.dbcon as dbcu
import edurel.widgets.mermaid_viz as mmw
import edurel.utils.mermaid as mm
import edurel.utils.misc as misc
import yaml


load_dotenv() 
BASE_DIR = os.getenv("BASE_DIR")
DB_DIR = f"{BASE_DIR}/databases"
ER_DIR = f"{BASE_DIR}/er/yaml"
# Out:
# /home/iclassen/.py1/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %% [markdown]
# # Mermaid Rel

# %%
# con = dbcu.adw_oltp()
# additional_fks = {}
# # additional_fks = {"OrgUnit": ["Employee|Head|EID", "OrgUnit|SuperUnit|OUID"]}
# db = dbu.DbHandler(con, additional_fks=additional_fks)
# mermaid = db.schema_mermaid(omit_tags=["nullable", "fkname"], direction="LR")

# %%
# viz = mmw.MermaidViz(mermaid, height="500px", width="100%")
# viz.display()

# %%
# db.schema_mermaid_png(output_path="schema.png", omit_tags=["nullable", "fkname"], direction="LR", width=2000, height=1000)
# db.schema_mermaid_png(output_path="schema.png", omit_tags=["nullable", "fkname"], direction="LR", scale=6)

# %% [markdown]
# # Mermaid ER

# %%
init_str = """
    ---
      config:
        class:
          hideEmptyMembersBox: true
    ---
    classDiagram
"""
print(misc.ml_unindent(init_str))
# Out:
# ---
#   config:
#     class:
#       hideEmptyMembersBox: true
# ---
# classDiagram

# %%
diagram = mm.ERDiagram.from_file(f"{ER_DIR}/t2.yaml")                                                                                                                           
mermaid_code = diagram.toMermaid()  
viz = mmw.MermaidViz(mermaid_code, height="800px", width="100%")
viz.display()
# Out:
#         <script src="https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js"></script>
#         <script>
#         if (typeof mermaid !== 'undefined') {
#             mermaid.initialize({ startOnLoad: true });
#         }
#         </script>
# Output(layout=Layout(height='800px', width='100%'))

# %%
print(mermaid_code)
# Out:
# ---
#   config:
#     class:
#       hideEmptyMembersBox: true
#     themeVariables:
#       primaryColor: "#00ff00"
# ---
#
# classDiagram
#
#     class VL1 {
#         +INTEGER ID
#         +TEXT Description
#         +BOOLEAN IsValid
#         +INTEGER SortOrder
#     }
#     class VL2 {
#         +INTEGER ID
#         +TEXT Description
#         +BOOLEAN IsValid
#         +INTEGER SortOrder
#     }
