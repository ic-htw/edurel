# %% [markdown]
# # Install / Import / Config

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from google import genai
from google.genai import types

import edurel.utils.llm as llmu

load_dotenv()
# Out:
# /home/iclassen/.pywork1/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# True

# %% [markdown]
# # Anthropic

# %%
client = anthropic.Anthropic()

message = client.messages.create(
    model=llmu.SONNET45,
    max_tokens=1024,
    messages=[
        {"role": "user", "content": "What is the capital of Germany?"}
    ]
)

print(message.content)
# Out:
# [TextBlock(citations=None, text='The capital of Germany is Berlin.', type='text')]

# %% [markdown]
# # Google

# %%
client = genai.Client()

response = client.models.generate_content(
    model=llmu.GEMINI3PRO, contents='What is the capital of Germany?'
)
print(response.text)

client.close()

# %% [markdown]
# # LLM-Stats

# %%
client = OpenAI(
    api_key=os.getenv("LLM_STATS_API_KEY"),
    base_url="https://api.zeroeval.com/v1"
)

response = client.chat.completions.create(
    model=llmu.GPT41MINI,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of Germany?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# The capital of Germany is Berlin.

# %% [markdown]
# # OpenAI

# %%
client = OpenAI()

response = client.chat.completions.create(
    model=llmu.GPT41MINI,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of Germany?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# The capital of Germany is Berlin.
