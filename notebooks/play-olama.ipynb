# %%
import requests
import json

import edurel.utils.duckdb as ddbu

BASE_DIR = "/home/basis/work/github/edurel"
DB_DIR = f"{BASE_DIR}/databases/"

# %%
con = ddbu.mem_con(f"{DB_DIR}/db-company_en")
schema = ddbu.schema(con)

# %%
url = 'https://wigpu01l.f4.htw-berlin.de:4000/api/generate'
# Benutzername und Passwort für die Basic Authentication
username = 'iclassen'
password = 'abc27b3_DBxy'

headers = {
    'Content-Type': 'application/json'
}
payload = {
    "model": "a-kore/Arctic-Text2SQL-R1-7B",
    "prompt": f"Explain the following database schema:\n{schema}\n",
    "stream": False
}

# POST-Anfrage an die API senden (mit Authentifizierung)
response = requests.post(url, json=payload, headers=headers, auth=(username, password), verify=False)  # verify=False ignoriert SSL-Zertifikat

# Antwort überprüfen
if response.status_code == 200:
    print("API-Aufruf erfolgreich:")
    try:
        # Lade JSON-Antwort und formatiere sie mit dem UTF-8 Zeichensatz
        response_data = response.json()
        formatted_response = json.dumps(response_data, indent=4, ensure_ascii=False).encode('utf-8')
        # print(formatted_response.decode())

        # Response formatiert ausgeben
        print(response_data['response'])  # Direkter Zugriff auf den Text der Antwort
    except json.JSONDecodeError as e:
        print(f"Fehler beim JSON-Decoding der Antwort: {e}")
else:
    print("Fehler beim API-Aufruf:")
    print(response.status_code, response.text)
# Out:
# /home/basis/.pyedurel/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'wigpu01l.f4.htw-berlin.de'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# API-Aufruf erfolgreich:
#  Given the natural language question, we have three tables and each table is linked with relations defined in foreign keys. The question itself does not explicitly mention what data it needs; however, from the context given about tables and their relations, it seems we should use all of them to extract a meaningful answer for any specific project or organization structure. In case we are required to show some details on an organization unit's hierarchy, employee salaries, projects associated with employees’ hours per week, or bonus plans, then the combination of these tables would be necessary.
# </think>
# ...
