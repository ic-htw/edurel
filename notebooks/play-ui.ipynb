# %% [markdown]
# # Import / Config

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from edurel.widgets.listman import ListManager
DATA_DIR = "/home/basis/work/github/edurel/data"

# %%
# Create manager
manager = ListManager(filename="tasks.json")
manager.display()

# %%
# Get selected items
manager.get_selected_items()

# %%
manager.selected_indices = [0]  # Example: select first and third items

# %%
from edurel.widgets.mermaid_viz import MermaidVisualizer
viz = MermaidVisualizer()
viz.display()
# Out:
#         <script src="https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js"></script>
#         <script>
#         if (typeof mermaid !== 'undefined') {
#             mermaid.initialize({ startOnLoad: true });
#         }
#         </script>
# ...

# %%
print(viz._create_mermaid_html(viz.mermaid_code))
# Out:
#         <div class="mermaid-container">
#             <script type="module">
#                 import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
#                 mermaid.initialize({ startOnLoad: true, theme: 'default' });
#             </script>
#             <div class="mermaid">
# erDiagram
#     users {
#         INTEGER id PK
#         TEXT username NOT_NULL
#         TEXT email NOT_NULL
#         DATETIME created_at
#     }
#             </div>
#         </div>

# %%
from edurel.widgets import SchemaVisualizer
viz = SchemaVisualizer(directory=DATA_DIR)
viz.display()

# %%
from IPython.display import display, HTML

display(HTML("""
<script src="https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js"></script>
<script>
mermaid.initialize({startOnLoad:true});
</script>
<div class="mermaid">
  graph TD;
    A-->B;
    A-->C;
    B-->D;
    C-->D;
</div>
                        
"""))
# Out:
# <script src="https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js"></script>
# <script>
# mermaid.initialize({startOnLoad:true});
# </script>
# <div class="mermaid">
#   graph TD;
#     A-->B;
#     A-->C;
#     B-->D;
#     C-->D;
# </div>

# %%
from IPython.display import HTML

mermaid_code = """
graph TD;
    A-->B;
    A-->C;
    B-->D;
    C-->D;
"""

HTML(f"""
<div class="mermaid">
{mermaid_code}
</div>
""")
# Out:
# <div class="mermaid">
#
# graph TD;
#     A-->B;
#     A-->C;
#     B-->D;
#     C-->D;
#
# </div>
